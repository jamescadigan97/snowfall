# %%
import pandas as pd
df = pd.read_csv('./2021-03-26.csv')

# %%
df
# Out:
#           Date              Resort_Name            Region        Country  \
# 0   2021-03-26               Afton Alps         Minnesota  United_States
# 1   2021-03-26     Alpine Valley Resort         Wisconsin  United_States
# 2   2021-03-26  Arapahoe Basin Ski Area          Colorado  United_States
# 3   2021-03-26                 Attitash     New_Hampshire  United_States
# 4   2021-03-26             Beaver Creek          Colorado  United_States
# ..         ...                      ...               ...            ...
# 61  2021-03-26       Whistler Blackcomb  British_Columbia         Canada
# 62  2021-03-26         Whitetail Resort      Pennsylvania  United_States
# 63  2021-03-26         Wildcat Mountain     New_Hampshire  United_States
# 64  2021-03-26          Wilmot Mountain         Wisconsin  United_States
# 65  2021-03-26              Winter Park          Colorado  United_States
#
#     Pass  Snowfall  Lower_Depth  Middle_Depth  Upper_Depth
# ...

# %%
df = df.sort_values(["date","resort_name"], ascending=(True,True))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-120c9cce5bcf> in <module>
# ----> 1 df = df.sort_values(["date","resort_name"], ascending=(True,True))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4918             from pandas.core.sorting import lexsort_indexer
#    4919
# -> 4920             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    4921             indexer = lexsort_indexer(keys, orders=ascending, na_position=na_position)
#    4922             indexer = ensure_platform_int(indexer)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in <listcomp>(.0)
#    4918             from pandas.core.sorting import lexsort_indexer
#    4919
# ...

# %%
df
# Out:
#           Date              Resort_Name            Region        Country  \
# 0   2021-03-26               Afton Alps         Minnesota  United_States
# 1   2021-03-26     Alpine Valley Resort         Wisconsin  United_States
# 2   2021-03-26  Arapahoe Basin Ski Area          Colorado  United_States
# 3   2021-03-26                 Attitash     New_Hampshire  United_States
# 4   2021-03-26             Beaver Creek          Colorado  United_States
# ..         ...                      ...               ...            ...
# 61  2021-03-26       Whistler Blackcomb  British_Columbia         Canada
# 62  2021-03-26         Whitetail Resort      Pennsylvania  United_States
# 63  2021-03-26         Wildcat Mountain     New_Hampshire  United_States
# 64  2021-03-26          Wilmot Mountain         Wisconsin  United_States
# 65  2021-03-26              Winter Park          Colorado  United_States
#
#     Pass  Snowfall  Lower_Depth  Middle_Depth  Upper_Depth
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#           Date              Resort_Name            Region        Country  \
# 0   2021-03-26               Afton Alps         Minnesota  United_States
# 1   2021-03-26     Alpine Valley Resort         Wisconsin  United_States
# 2   2021-03-26  Arapahoe Basin Ski Area          Colorado  United_States
# 3   2021-03-26                 Attitash     New_Hampshire  United_States
# 4   2021-03-26             Beaver Creek          Colorado  United_States
# ..         ...                      ...               ...            ...
# 61  2021-03-26       Whistler Blackcomb  British_Columbia         Canada
# 62  2021-03-26         Whitetail Resort      Pennsylvania  United_States
# 63  2021-03-26         Wildcat Mountain     New_Hampshire  United_States
# 64  2021-03-26          Wilmot Mountain         Wisconsin  United_States
# 65  2021-03-26              Winter Park          Colorado  United_States
#
#     Pass  Snowfall  Lower_Depth  Middle_Depth  Upper_Depth
# ...

# %%
#df.to_csv("full_szn.csv", index=False)

# %%
df.Resort_Name.unique()
# Out:
# array(['Afton Alps', 'Alpine Valley Resort', 'Arapahoe Basin Ski Area',
#        'Attitash', 'Beaver Creek', 'Big Boulder', 'Big Sky',
#        'Blue Mountain', 'Boston Mills', 'Boyne Highlands',
#        'Boyne Mountain Resort', 'Brandywine', 'Breckenridge',
#        'Brighton Resort', 'Coronet Peak', 'Crested Butte Mountain Resort',
#        'Crotched Mountain', 'Crystal Mountain', 'Cypress Mountain',
#        'Falls Creek Alpine Resort', 'Heavenly', 'Hidden Valley Resort',
#        'Jack Frost', 'June Mountain', 'Keystone', 'Kirkwood', 'Liberty',
#        'Loon Mountain', 'Mad River Mountain', 'Mammoth Mountain',
#        'Mount Snow', 'Mount Sunapee', 'Mt. Brighton', 'Mt. Buller',
#        'Mt. Hotham', 'Mt. Hutt Ski Area', 'Northstar California',
#        'Okemo Mountain Resort', 'Paoli Peaks', 'Park City', 'Perisher',
#        'Revelstoke', 'Roundtop Mountain Resort', 'Snow Creek',
#        'Snowshoe Mountain', 'Solitude Mountain Resort',
# ...

# %%
df.Region.unique()
# Out:
# array(['Minnesota', 'Wisconsin', 'Colorado', 'New_Hampshire',
#        'Pennsylvania', 'Montana', 'Ontario', 'Ohio', 'Michigan', 'Utah',
#        'New_Zealand', 'Washington', 'British_Columbia', 'Australia',
#        'California', 'Vermont', 'Indiana', 'Missouri', 'West_Virginia',
#        'Maine', 'New_Mexico', 'Quebec', 'Chile'], dtype=object)

# %%
df.Country.unique()
# Out:
# array(['United_States', 'Canada', 'New_Zealand', 'Australia', 'Chile'],
#       dtype=object)
