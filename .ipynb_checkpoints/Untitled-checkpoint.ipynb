# %%
import pandas as pd
df = pd.read_csv('./full_season.csv')

# %%
df = df.sort_values(["date","resort_name"], ascending=(True,True))

# %%
df
# Out:
#             date                        resort_name            region  \
# 0     2020-12-27                         Afton Alps         Minnesota
# 1     2020-12-27  Alpe Cimbra - Folgaria - Lavarone          Trentino
# 2     2020-12-27                      Alta Ski Area              Utah
# 3     2020-12-27       Andalo - Fai della Paganella          Trentino
# 4     2020-12-27            Arapahoe Basin Ski Area          Colorado
# ...          ...                                ...               ...
# 6667  2021-04-01                 Whistler Blackcomb  British_Columbia
# 6668  2021-04-01                   Whitetail Resort      Pennsylvania
# 6669  2021-04-01                   Wildcat Mountain     New_Hampshire
# 6670  2021-04-01                    Wilmot Mountain         Wisconsin
# 6671  2021-04-01                        Winter Park          Colorado
#
#             country  pass  snowfall
# 0     United_States  EPIC         0
# 1             Italy  EPIC         0
# 2     United_States  IKON         2
# 3             Italy  EPIC         0
# 4     United_States  IKON         0
# ...             ...   ...       ...
# 6667         Canada  EPIC         0
# 6668  United_States  EPIC         0
# 6669  United_States  EPIC         2
# 6670  United_States  EPIC         0
# 6671  United_States  IKON         0
#
# [6672 rows x 6 columns]

# %%
df.to_csv("full_szn.csv")
