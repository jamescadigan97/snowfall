# %%
#MAKE SURE TO RESTART
#Check time Delta
#days_ = 2
days_ = 2
week_day = 5 - days_
print(week_day)
# Out:
# 3

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
from datetime import date
import psycopg2
import pandas as pd
from datetime import timedelta
# Out:
# /Users/jamescadigan/opt/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
base_url = 'https://www.onthesnow.com'
#break
epic_href= ['/new-hampshire/attitash/skireport.html','/vermont/mount-snow/skireport.html','/new-hampshire/crotched-mountain/skireport.html','/pennsylvania/liberty/skireport.html',\
            '/new-hampshire/mount-sunapee/skireport.html','/vermont/okemo-mountain-resort/skireport.html','/vermont/stowe-mountain-resort/skireport.html','/pennsylvania/roundtop-mountain-resort/skireport.html',\
            '/pennsylvania/jack-frost/skireport.html','/pennsylvania/whitetail-resort/skireport.html','/new-hampshire/wildcat-mountain/skireport.html','/colorado/vail/skireport.html','/colorado/breckenridge/skireport.html','/colorado/beaver-creek/skireport.html',\
            '/utah/park-city-mountain-resort/skireport.html','/colorado/keystone/skireport.html','/colorado/crested-butte-mountain-resort/skireport.html','/california/heavenly-mountain-resort/skireport.html','/california/northstar-california/skireport.html',\
            '/california/kirkwood/skireport.html','/washington/stevens-pass-resort/skireport.html','/pennsylvania/big-boulder/skireport.html','/wisconsin/wilmot-mountain/skireport.html','/minnesota/afton-alps/skireport.html','/michigan/mount-brighton/skireport.html',\
            '/wisconsin/alpine-valley-resort/skireport.html','/ohio/boston-mills/skireport.html','/ohio/brandywine/skireport.html','/ohio/mad-river-mountain/skireport.html','/pennsylvania/hidden-valley-resort/skireport.html','/missouri/snow-creek/skireport.html',\
            '/indiana/paoli-peaks/skireport.html','/british-columbia/whistler-blackcomb/skireport.html','/australia/mt-hotham/skireport.html','/australia/perisher/skireport.html','/australia/falls-creek-alpine-resort/skireport.html']

ikon_href = ['/colorado/steamboat/skireport.html','/colorado/winter-park-resort/skireport.html','/colorado/arapahoe-basin-ski-area/skireport.html','/california/squaw-valley-usa/skireport.html',\
             '/california/mammoth-mountain-ski-area/skireport.html','/california/june-mountain/skireport.html','/montana/big-sky-resort/skireport.html',\
             '/vermont/stratton-mountain/skireport.html','/vermont/sugarbush/skireport.html','/west-virginia/snowshoe-mountain-resort/skireport.html','/michigan/boyne-highlands/skireport.html',\
             '/michigan/boyne-mountain-resort/skireport.html','/washington/crystal-mountain-wa/skireport.html','/washington/the-summit-at-snoqualmie/skireport.html','/quebec/tremblant/skireport.html',\
             '/ontario/blue-mountain/skireport.html','/british-columbia/revelstoke-mountain/skireport.html','/british-columbia/cypress-mountain/skireport.html','/maine/sunday-river/skireport.html','/maine/sugarloaf/skireport.html','/new-hampshire/loon-mountain/skireport.html',\
             '/new-mexico/taos-ski-valley/skireport.html','/utah/solitude-mountain-resort/skireport.html','/utah/brighton-resort/skireport.html','/australia/thredbo-alpine-resort/skireport.html','/australia/mt-buller/skireport.html','/chile/valle-nevado/skireport.html',\
             '/new-zealand/coronet-peak/skireport.html','/new-zealand/the-remarkables/skireport.html','/new-zealand/mt-hutt-ski-area/skireport.html']
print(f"{base_url}{epic_href[0]}")
# Out:
# https://www.onthesnow.com/new-hampshire/attitash/skireport.html

# %%
snowfall_df = pd.DataFrame(columns = ['Date', 'Resort_Name','Region','Country', 'Pass','Snowfall','Lower_Depth','Middle_Depth','Upper_Depth'])
snowfall_df
# Out:
# Empty DataFrame
# Columns: [Date, Resort_Name, Region, Country, Pass, Snowfall, Lower_Depth, Middle_Depth, Upper_Depth]
# Index: []

# %%
#EPIC PASS
for x in range (0, len(epic_href)):
#for x in range (1, 3):
    url = f"{base_url}{epic_href[x]}"
    options = Options()
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')  
    browser = webdriver.Chrome(options=options)
    browser.get(url)
    html = browser.page_source
    time.sleep(10)
    soup = BeautifulSoup(html, "lxml")
    today_date = date.today()
    today_date = today_date - timedelta(days=days_)
    
    #Parse text
    print('-----------------------')
    print(f"Result #{x+1} out of 36")
    try:
        name = soup.find('span', class_="resort_name").text
    except:
        name_ = epic_href[x].split("/")
        print("!!!!")
        name = name_[2]
    location_ = epic_href[x].split("/")
    location= location_[1]
    today_ = soup.findAll('div' , class_="predicted_snowfall")
    #today = today_[5].find('div', class_="bluePill").text
    today = today_[week_day].find('div', class_="bluePill").text
    try:
        upper = soup.find('li', class_="elevation upper").find('div', class_="bluePill").text
    except:
        upper = str("N/A")
    try:
        mid = soup.find('li', class_="elevation middle").find('div', class_="bluePill").text
    except:
        mid = str("N/A")
    try:
        lower = soup.find('li', class_="elevation lower").find('div', class_="bluePill").text
    except:
        lower = str("N/A")
    #Format
    try:
        upper = upper.replace('"', '')
        upper = int(upper)
    except:
        upper = str("N/A")
    try:
        mid = mid.replace('"', '')
        mid = int(mid)
    except:
        mid = str("N/A")
    try:
        lower = lower.replace('"', '')
        lower = int(lower)
    except:
        lower = str("N/A")
    try:
        today = today.replace('"', '')
        today = int(today)
    except:
        today = str("N/A")
    pass_ = str("EPIC")
    try:
        location = location.replace('-', ' ')
    except:
        location = location
    location = location.title()
    try:
        location = location.replace(' ', '_')
    except:
        location = location
    if location =="Trentino":
        country = "Italy"
    elif location =="British_Columbia":
        country = "Canada"
    elif location =="Washington":
        country = "United_States"
    elif location =="Northern_Alps":
        country = "France"
    elif location =="California":
        country = "United_States"
    elif location =="Valais":
        country = "Switzerland"
    elif location =="Alberta":
        country = "Canada"
    elif location =="Vermont":
        country = "United_States"
    elif location =="Idaho":
        country = "United_States"
    elif location =="Utah":
        country = "United_States"
    elif location =="Colorado":
        country = "United_States"
    elif location =="Michigan":
        country = "United_States"
    elif location =="Minnesota":
        country = "United_States"
    elif location =="Wisconsin":
        country = "United_States"
    elif location =="New_Hampshire":
        country = "United_States"
    elif location =="Quebec":
        country = "Canada"
    elif location =="Ohio":
        country = "United_States"
    elif location =="Australia":
        country = "Australia"
    elif location =="Wyoming":
        country = "United_States"
    elif location =="Oregon":
        country = "United_States"
    elif location =="West_Virginia":
        country = "United_States"
    elif location =="Montana":
        country = "United_States"
    elif location =="New_York":
        country = "United_States"
    elif location =="Ontario":
        country = "Canada"
    elif location =="Maine":
        country = "United_States"
    elif location =="New_Mexico":
        country = "United_States"
    elif location =="Pennsylvania":
        country = "United_States"
    elif location =="Missouri":
        country = "United_States"
    elif location =="Indiana":
        country = "United_States"     
    else:
        country = location
    
    #Print Results
    print(today_date)
    print(f"Resort name: {name}")
    print(f"Region: {location}")
    print(f"Country: {country}")
    print(f"Pass: {pass_}")
    print(f"Today's snowfall: {today}")
    print(f"Upper depth: {upper}")
    print(f"Mid depth: {mid}")
    print(f"Lower depth: {lower}")
    browser.quit()

    #Save results to Dataframe
    snowfall_df = snowfall_df.append({'Date': today_date, 'Resort_Name': name,'Region': location,'Country': country, 'Pass':pass_,\
    'Snowfall':today,'Lower_Depth':lower, 'Middle_Depth': mid,'Upper_Depth': upper}, ignore_index=True)
# Out:
# -----------------------
# Result #1 out of 36
# 2021-03-06
# Resort name: Attitash
# Region: New_Hampshire
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 32
# Mid depth: N/A
# Lower depth: 32
# -----------------------
# Result #2 out of 36
# 2021-03-06
# Resort name: Mount Snow
# Region: Vermont
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 41
# Mid depth: N/A
# Lower depth: 41
# -----------------------
# Result #3 out of 36
# 2021-03-06
# Resort name: Crotched Mountain
# Region: New_Hampshire
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 30
# Mid depth: N/A
# Lower depth: 15
# -----------------------
# Result #4 out of 36
# 2021-03-06
# Resort name: Liberty
# Region: Pennsylvania
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 16
# Mid depth: N/A
# Lower depth: 12
# -----------------------
# Result #5 out of 36
# 2021-03-06
# Resort name: Mount Sunapee
# Region: New_Hampshire
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 32
# Mid depth: N/A
# Lower depth: 32
# -----------------------
# Result #6 out of 36
# 2021-03-06
# Resort name: Okemo Mountain Resort
# Region: Vermont
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 35
# Mid depth: N/A
# Lower depth: 29
# -----------------------
# Result #7 out of 36
# 2021-03-06
# Resort name: Stowe Mountain
# Region: Vermont
# Country: United_States
# Pass: EPIC
# Today's snowfall: 1
# Upper depth: 60
# Mid depth: 40
# Lower depth: 30
# -----------------------
# Result #8 out of 36
# 2021-03-06
# Resort name: Roundtop Mountain Resort
# Region: Pennsylvania
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 20
# Mid depth: N/A
# Lower depth: 20
# -----------------------
# Result #9 out of 36
# 2021-03-06
# Resort name: Jack Frost
# Region: Pennsylvania
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 30
# Mid depth: N/A
# Lower depth: 24
# -----------------------
# Result #10 out of 36
# 2021-03-06
# Resort name: Whitetail Resort
# Region: Pennsylvania
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 32
# Mid depth: N/A
# Lower depth: 32
# -----------------------
# Result #11 out of 36
# 2021-03-06
# Resort name: Wildcat Mountain
# Region: New_Hampshire
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 36
# Mid depth: N/A
# Lower depth: 18
# -----------------------
# Result #12 out of 36
# 2021-03-06
# Resort name: Vail
# Region: Colorado
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 51
# Mid depth: 51
# Lower depth: 51
# -----------------------
# Result #13 out of 36
# 2021-03-06
# Resort name: Breckenridge
# Region: Colorado
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 47
# Mid depth: 47
# Lower depth: 47
# -----------------------
# Result #14 out of 36
# 2021-03-06
# Resort name: Beaver Creek
# Region: Colorado
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 40
# Mid depth: 40
# Lower depth: 40
# -----------------------
# Result #15 out of 36
# 2021-03-06
# Resort name: Park City
# Region: Utah
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 70
# Mid depth: 58
# Lower depth: 50
# -----------------------
# Result #16 out of 36
# 2021-03-06
# Resort name: Keystone
# Region: Colorado
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 40
# Mid depth: 40
# Lower depth: 40
# -----------------------
# Result #17 out of 36
# 2021-03-06
# Resort name: Crested Butte Mountain Resort
# Region: Colorado
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 53
# Mid depth: 53
# Lower depth: 53
# -----------------------
# Result #18 out of 36
# 2021-03-06
# Resort name: Heavenly
# Region: California
# Country: United_States
# Pass: EPIC
# Today's snowfall: 4
# Upper depth: 72
# Mid depth: 56
# Lower depth: 46
# -----------------------
# Result #19 out of 36
# 2021-03-06
# Resort name: Northstar California
# Region: California
# Country: United_States
# Pass: EPIC
# Today's snowfall: 4
# Upper depth: 70
# Mid depth: N/A
# Lower depth: 18
# -----------------------
# Result #20 out of 36
# 2021-03-06
# Resort name: Kirkwood
# Region: California
# Country: United_States
# Pass: EPIC
# Today's snowfall: 1
# Upper depth: 63
# Mid depth: 56
# Lower depth: 65
# -----------------------
# Result #21 out of 36
# 2021-03-06
# Resort name: Stevens Pass Resort
# Region: Washington
# Country: United_States
# Pass: EPIC
# Today's snowfall: 3
# Upper depth: 169
# Mid depth: 159
# Lower depth: 126
# -----------------------
# Result #22 out of 36
# 2021-03-06
# Resort name: Big Boulder
# Region: Pennsylvania
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: N/A
# Mid depth: N/A
# Lower depth: N/A
# -----------------------
# Result #23 out of 36
# 2021-03-06
# Resort name: Wilmot Mountain
# Region: Wisconsin
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 20
# Mid depth: N/A
# Lower depth: 20
# -----------------------
# Result #24 out of 36
# 2021-03-06
# Resort name: Afton Alps
# Region: Minnesota
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 24
# Mid depth: N/A
# Lower depth: 12
# -----------------------
# Result #25 out of 36
# 2021-03-06
# Resort name: Mt. Brighton
# Region: Michigan
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 35
# Mid depth: 35
# Lower depth: 35
# -----------------------
# Result #26 out of 36
# 2021-03-06
# Resort name: Alpine Valley Resort
# Region: Wisconsin
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 18
# Mid depth: N/A
# Lower depth: 8
# -----------------------
# Result #27 out of 36
# 2021-03-06
# Resort name: Boston Mills
# Region: Ohio
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 18
# Mid depth: N/A
# Lower depth: 10
# -----------------------
# Result #28 out of 36
# 2021-03-06
# Resort name: Brandywine
# Region: Ohio
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 18
# Mid depth: N/A
# Lower depth: 10
# -----------------------
# Result #29 out of 36
# 2021-03-06
# Resort name: Mad River Mountain
# Region: Ohio
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 24
# Mid depth: N/A
# Lower depth: N/A
# -----------------------
# Result #30 out of 36
# 2021-03-06
# Resort name: Hidden Valley Resort
# Region: Pennsylvania
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 54
# Mid depth: N/A
# Lower depth: 42
# -----------------------
# Result #31 out of 36
# 2021-03-06
# Resort name: Snow Creek
# Region: Missouri
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 20
# Mid depth: N/A
# Lower depth: 20
# -----------------------
# Result #32 out of 36
# 2021-03-06
# Resort name: Paoli Peaks
# Region: Indiana
# Country: United_States
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: N/A
# Mid depth: N/A
# Lower depth: N/A
# -----------------------
# Result #33 out of 36
# 2021-03-06
# Resort name: Whistler Blackcomb
# Region: British_Columbia
# Country: Canada
# Pass: EPIC
# Today's snowfall: 1
# Upper depth: 118
# Mid depth: 118
# Lower depth: 118
# -----------------------
# Result #34 out of 36
# 2021-03-06
# Resort name: Mt. Hotham
# Region: Australia
# Country: Australia
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 0
# Mid depth: 0
# Lower depth: 0
# -----------------------
# Result #35 out of 36
# 2021-03-06
# Resort name: Perisher
# Region: Australia
# Country: Australia
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 0
# Mid depth: 0
# Lower depth: 0
# -----------------------
# Result #36 out of 36
# 2021-03-06
# Resort name: Falls Creek Alpine Resort
# Region: Australia
# Country: Australia
# Pass: EPIC
# Today's snowfall: 0
# Upper depth: 0
# Mid depth: N/A
# Lower depth: 0

# %%
#IKON PASS
for x in range (0, len(ikon_href)):
#for x in range (1, 3):
    url = f"{base_url}{ikon_href[x]}"
    options = Options()
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')  
    browser = webdriver.Chrome(options=options)
    browser.get(url)
    html = browser.page_source
    time.sleep(15)
    soup = BeautifulSoup(html, "lxml")
    today_date = date.today()
    today_date = today_date - timedelta(days=days_)
    
    #Parse text
    print('-----------------------')
    print(f"Result #{x+1} out of 30")
    name = soup.find('span', class_="resort_name").text
    location_ = ikon_href[x].split("/")
    location= location_[1]
    today_ = soup.findAll('div' , class_="predicted_snowfall")
    #today = today_[5].find('div', class_="bluePill").text
    today = today_[week_day].find('div', class_="bluePill").text
    try:
        upper = soup.find('li', class_="elevation upper").find('div', class_="bluePill").text
    except:
        upper = str("N/A")
    try:
        mid = soup.find('li', class_="elevation middle").find('div', class_="bluePill").text
    except:
        mid = str("N/A")
    try:
        lower = soup.find('li', class_="elevation lower").find('div', class_="bluePill").text
    except:
        lower = str("N/A")
    #Format
    try:
        upper = upper.replace('"', '')
        upper = int(upper)
    except:
        upper = str("N/A")
    try:
        mid = mid.replace('"', '')
        mid = int(mid)
    except:
        mid = str("N/A")
    pass_ = str("IKON")
    try:
        lower = lower.replace('"', '')
        lower = int(lower)
    except:
        lower = str("N/A")
    try:
        today = today.replace('"', '')
        today = int(today)
    except:
        today = str("N/A")
    try:
        location = location.replace('-', ' ')
    except:
        location = location
    location = location.title()
    try:
        location = location.replace(' ', '_')
    except:
        location = location
        
    if location =="Trentino":
        country = "Italy"
    elif location =="British_Columbia":
        country = "Canada"
    elif location =="Washington":
        country = "United_States"
    elif location =="Northern_Alps":
        country = "France"
    elif location =="California":
        country = "United_States"
    elif location =="Valais":
        country = "Switzerland"
    elif location =="Alberta":
        country = "Canada"
    elif location =="Vermont":
        country = "United_States"
    elif location =="Idaho":
        country = "United_States"
    elif location =="Utah":
        country = "United_States"
    elif location =="Colorado":
        country = "United_States"
    elif location =="Michigan":
        country = "United_States"
    elif location =="Minnesota":
        country = "United_States"
    elif location =="Wisconsin":
        country = "United_States"
    elif location =="New_Hampshire":
        country = "United_States"
    elif location =="Quebec":
        country = "Canada"
    elif location =="Ohio":
        country = "United_States"
    elif location =="Australia":
        country = "Australia"
    elif location =="Wyoming":
        country = "United_States"
    elif location =="Oregon":
        country = "United_States"
    elif location =="West_Virginia":
        country = "United_States"
    elif location =="Montana":
        country = "United_States"
    elif location =="New_York":
        country = "United_States"
    elif location =="Ontario":
        country = "Canada"
    elif location =="Maine":
        country = "United_States"
    elif location =="New_Mexico":
        country = "United_States"
    elif location =="Pennsylvania":
        country = "United_States"
    elif location =="Missouri":
        country = "United_States"
    elif location =="Indiana":
        country = "United_States"     
    else:
        country = location        

    #Print Results
    print(today_date)
    print(f"Resort name: {name}")
    print(f"Region: {location}")
    print(f"Country: {country}")
    print(f"Pass: {pass_}")
    print(f"Today's snowfall: {today}")
    print(f"Upper depth: {upper}")
    print(f"Mid depth: {mid}")
    print(f"Lower depth: {lower}")
    browser.quit()

    #Save results to Dataframe
    snowfall_df = snowfall_df.append({'Date': today_date, 'Resort_Name': name,'Region': location,'Country': country,'Pass':pass_,\
    'Snowfall':today,'Lower_Depth':lower, 'Middle_Depth': mid,'Upper_Depth': upper}, ignore_index=True)
# Out:
# -----------------------
# Result #1 out of 30
# 2021-03-06
# Resort name: Steamboat
# Region: Colorado
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 73
# Mid depth: 48
# Lower depth: 48
# -----------------------
# Result #2 out of 30
# 2021-03-06
# Resort name: Winter Park
# Region: Colorado
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 31
# Mid depth: N/A
# Lower depth: 60
# -----------------------
# Result #3 out of 30
# 2021-03-06
# Resort name: Arapahoe Basin Ski Area
# Region: Colorado
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 47
# Mid depth: 47
# Lower depth: 47
# -----------------------
# Result #4 out of 30
# 2021-03-06
# Resort name: Squaw Valley Alpine Meadows
# Region: California
# Country: United_States
# Pass: IKON
# Today's snowfall: 3
# Upper depth: N/A
# Mid depth: 111
# Lower depth: 67
# -----------------------
# Result #5 out of 30
# 2021-03-06
# Resort name: Mammoth Mountain
# Region: California
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 90
# Mid depth: 95
# Lower depth: 60
# -----------------------
# Result #6 out of 30
# 2021-03-06
# Resort name: June Mountain
# Region: California
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 60
# Mid depth: N/A
# Lower depth: 42
# -----------------------
# Result #7 out of 30
# 2021-03-06
# Resort name: Big Sky
# Region: Montana
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 79
# Mid depth: 53
# Lower depth: 51
# -----------------------
# Result #8 out of 30
# 2021-03-06
# Resort name: Stratton Mountain
# Region: Vermont
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 24
# Mid depth: 24
# Lower depth: 24
# -----------------------
# Result #9 out of 30
# 2021-03-06
# Resort name: Sugarbush
# Region: Vermont
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 72
# Mid depth: N/A
# Lower depth: 48
# -----------------------
# Result #10 out of 30
# 2021-03-06
# Resort name: Snowshoe Mountain
# Region: West_Virginia
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 50
# Mid depth: N/A
# Lower depth: 50
# -----------------------
# Result #11 out of 30
# 2021-03-06
# Resort name: Boyne Highlands
# Region: Michigan
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 47
# Mid depth: N/A
# Lower depth: 47
# -----------------------
# Result #12 out of 30
# 2021-03-06
# Resort name: Boyne Mountain Resort
# Region: Michigan
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 48
# Mid depth: N/A
# Lower depth: 48
# -----------------------
# Result #13 out of 30
# 2021-03-06
# Resort name: Crystal Mountain
# Region: Washington
# Country: United_States
# Pass: IKON
# Today's snowfall: 1
# Upper depth: 136
# Mid depth: 136
# Lower depth: 96
# -----------------------
# Result #14 out of 30
# 2021-03-06
# Resort name: The Summit at Snoqualmie
# Region: Washington
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 121
# Mid depth: N/A
# Lower depth: N/A
# -----------------------
# Result #15 out of 30
# 2021-03-06
# Resort name: Tremblant
# Region: Quebec
# Country: Canada
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 50
# Mid depth: N/A
# Lower depth: 30
# -----------------------
# Result #16 out of 30
# 2021-03-06
# Resort name: Blue Mountain
# Region: Ontario
# Country: Canada
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 43
# Mid depth: N/A
# Lower depth: N/A
# -----------------------
# Result #17 out of 30
# 2021-03-06
# Resort name: Revelstoke
# Region: British_Columbia
# Country: Canada
# Pass: IKON
# Today's snowfall: 8
# Upper depth: 163
# Mid depth: N/A
# Lower depth: 99
# -----------------------
# Result #18 out of 30
# 2021-03-06
# Resort name: Cypress Mountain
# Region: British_Columbia
# Country: Canada
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 180
# Mid depth: N/A
# Lower depth: 106
# -----------------------
# Result #19 out of 30
# 2021-03-06
# Resort name: Sunday River
# Region: Maine
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 38
# Mid depth: N/A
# Lower depth: 22
# -----------------------
# Result #20 out of 30
# 2021-03-06
# Resort name: Sugarloaf
# Region: Maine
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 28
# Mid depth: 25
# Lower depth: 22
# -----------------------
# Result #21 out of 30
# 2021-03-06
# Resort name: Loon Mountain
# Region: New_Hampshire
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 36
# Mid depth: N/A
# Lower depth: 28
# -----------------------
# Result #22 out of 30
# 2021-03-06
# Resort name: Taos Ski Valley
# Region: New_Mexico
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 66
# Mid depth: 66
# Lower depth: 54
# -----------------------
# Result #23 out of 30
# 2021-03-06
# Resort name: Solitude Mountain Resort
# Region: Utah
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 69
# Mid depth: N/A
# Lower depth: 43
# -----------------------
# Result #24 out of 30
# 2021-03-06
# Resort name: Brighton Resort
# Region: Utah
# Country: United_States
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 78
# Mid depth: N/A
# Lower depth: N/A
# -----------------------
# Result #25 out of 30
# 2021-03-06
# Resort name: Thredbo Alpine Resort
# Region: Australia
# Country: Australia
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 0
# Mid depth: N/A
# Lower depth: 0
# -----------------------
# Result #26 out of 30
# 2021-03-06
# Resort name: Mt. Buller
# Region: Australia
# Country: Australia
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 0
# Mid depth: N/A
# Lower depth: 0
# -----------------------
# Result #27 out of 30
# 2021-03-06
# Resort name: Valle Nevado
# Region: Chile
# Country: Chile
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 0
# Mid depth: 0
# Lower depth: 0
# -----------------------
# Result #28 out of 30
# 2021-03-06
# Resort name: Coronet Peak
# Region: New_Zealand
# Country: New_Zealand
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 0
# Mid depth: N/A
# Lower depth: 0
# -----------------------
# Result #29 out of 30
# 2021-03-06
# Resort name: The Remarkables
# Region: New_Zealand
# Country: New_Zealand
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 0
# Mid depth: N/A
# Lower depth: 0
# -----------------------
# Result #30 out of 30
# 2021-03-06
# Resort name: Mt. Hutt Ski Area
# Region: New_Zealand
# Country: New_Zealand
# Pass: IKON
# Today's snowfall: 0
# Upper depth: 0
# Mid depth: N/A
# Lower depth: 0

# %%
snowfall_df = snowfall_df.sort_values("Resort_Name")

# %%
snowfall_df.to_csv('Snowfall.csv', index=False)

# %%
snowfall_df.to_csv(f'{today_date}.csv', index=False)

# %%
snowfall_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 23 to 37
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          66 non-null     object
#  1   Resort_Name   66 non-null     object
#  2   Region        66 non-null     object
#  3   Country       66 non-null     object
#  4   Pass          66 non-null     object
#  5   Snowfall      66 non-null     object
#  6   Lower_Depth   66 non-null     object
#  7   Middle_Depth  66 non-null     object
#  8   Upper_Depth   66 non-null     object
# dtypes: object(9)
# memory usage: 5.2+ KB

# %%
snowfall_df.to_csv(f'./Data_post_trip/{today_date}.csv', index=False)

# %%
snowfall_df.tail(66)
# Out:
#           Date              Resort_Name            Region        Country  \
# 23  2021-03-06               Afton Alps         Minnesota  United_States
# 25  2021-03-06     Alpine Valley Resort         Wisconsin  United_States
# 38  2021-03-06  Arapahoe Basin Ski Area          Colorado  United_States
# 0   2021-03-06                 Attitash     New_Hampshire  United_States
# 13  2021-03-06             Beaver Creek          Colorado  United_States
# ..         ...                      ...               ...            ...
# 32  2021-03-06       Whistler Blackcomb  British_Columbia         Canada
# 9   2021-03-06         Whitetail Resort      Pennsylvania  United_States
# 10  2021-03-06         Wildcat Mountain     New_Hampshire  United_States
# 22  2021-03-06          Wilmot Mountain         Wisconsin  United_States
# 37  2021-03-06              Winter Park          Colorado  United_States
#
#     Pass Snowfall Lower_Depth Middle_Depth Upper_Depth
# 23  EPIC        0          12          N/A          24
# 25  EPIC        0           8          N/A          18
# 38  IKON        0          47           47          47
# 0   EPIC        0          32          N/A          32
# 13  EPIC        0          40           40          40
# ..   ...      ...         ...          ...         ...
# 32  EPIC        1         118          118         118
# 9   EPIC        0          32          N/A          32
# 10  EPIC        0          18          N/A          36
# 22  EPIC        0          20          N/A          20
# 37  IKON        0          60          N/A          31
#
# [66 rows x 9 columns]
