# %%
import pandas as pd
snow06 = '0106.csv'
snow_df = pd.read_csv(snow06)
#pd.set_option('precision', 0)

# %%
snow_df
# Out:
#           Date                        Resort_Name            Region  \
# 0   2021-01-07                         Afton Alps         Minnesota
# 1   2021-01-07  Alpe Cimbra - Folgaria - Lavarone          Trentino
# 2   2021-01-07                      Alta Ski Area              Utah
# 3   2021-01-07       Andalo - Fai della Paganella          Trentino
# 4   2021-01-07            Arapahoe Basin Ski Area          Colorado
# ..         ...                                ...               ...
# 85  2021-01-07                          Veysonnaz            Valais
# 86  2021-01-07                 Whistler Blackcomb  British_Columbia
# 87  2021-01-07                    Wilmot Mountain         Wisconsin
# 88  2021-01-07                   Windham Mountain          New_York
# 89  2021-01-07                        Winter Park          Colorado
#
#           Country  Pass  Snowfall  Lower_Depth  Middle_Depth  Upper_Depth
# 0   United_States  EPIC         0         12.0           NaN         24.0
# ...

# %%
snow_df['Date'] = pd.to_datetime(snow_df['Date'])
snow_df['Date'] =snow_df['Date'] + pd.DateOffset(-1)
snow_df['Date'] = snow_df['Date'].astype(str)
#snow_df["Lower_Depth"]=snow_df["Lower_Depth"].astype(int)

# %%
snow_df.to_csv('0106_.csv')
snow_df
# Out:
#           Date                        Resort_Name            Region  \
# 0   2021-01-06                         Afton Alps         Minnesota
# 1   2021-01-06  Alpe Cimbra - Folgaria - Lavarone          Trentino
# 2   2021-01-06                      Alta Ski Area              Utah
# 3   2021-01-06       Andalo - Fai della Paganella          Trentino
# 4   2021-01-06            Arapahoe Basin Ski Area          Colorado
# ..         ...                                ...               ...
# 85  2021-01-06                          Veysonnaz            Valais
# 86  2021-01-06                 Whistler Blackcomb  British_Columbia
# 87  2021-01-06                    Wilmot Mountain         Wisconsin
# 88  2021-01-06                   Windham Mountain          New_York
# 89  2021-01-06                        Winter Park          Colorado
#
#           Country  Pass  Snowfall  Lower_Depth  Middle_Depth  Upper_Depth
# 0   United_States  EPIC         0         12.0           NaN         24.0
# ...
